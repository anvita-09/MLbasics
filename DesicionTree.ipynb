# %% [markdown]
# <a href="https://colab.research.google.com/github/anvita-09/MLbasics/blob/main/DesicionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
import pandas as pd
import io

print("Please upload your dataset file (e.g., CSV).")
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  # Assuming the uploaded file is a CSV. If it's a different format (like Excel),
  # you'll need to use a different pandas read function (e.g., pd.read_excel).
  df_uploaded = pd.read_csv(io.StringIO(uploaded[fn].decode('utf-8')))
  print("Uploaded DataFrame head:")
  print(df_uploaded.head())

# The uploaded dataframe is now in 'df_uploaded'. You can rename it or use it as needed.
# For example, to assign it to your 'inputs' variable, you might do:
# inputs = df_uploaded.copy()
# Or process it further depending on your dataset structure.
# Out:
# Please upload your dataset file (e.g., CSV).
#      <input type="file" id="files-5742043a-38b2-48a6-ab15-486e34c1aba5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5742043a-38b2-48a6-ab15-486e34c1aba5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
inputs = df.drop('Survived',axis='columns')

# %%
target = df['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_Pclass = LabelEncoder()
le_Sex = LabelEncoder()
le_Age = LabelEncoder()
le_Fare = LabelEncoder()

# %%
inputs['Pclass_n'] = le_Pclass.fit_transform(inputs['Pclass'])
inputs['Sex_n'] = le_Sex.fit_transform(inputs['Sex'])
inputs['Age_n'] = le_Age.fit_transform(inputs['Age'])
inputs['Fare_n'] = le_Fare.fit_transform(inputs['Fare'])

# %%
inputs_n = inputs[['Pclass_n','Sex_n','Age_n','Fare_n']]

# %%
inputs_n
# Out:
#      Pclass_n  Sex_n  Age_n  Fare_n
# 0           2      1     28      18
# 1           0      0     51     207
# 2           2      0     34      41
# 3           0      0     47     189
# 4           2      1     47      43
# ..        ...    ...    ...     ...
# 886         1      1     35      85
# 887         0      0     24     153
# 888         2      0     88     131
# 889         0      1     34     153
# 890         2      1     42      30
#
# [891 rows x 4 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 0.9797979797979798

# %%
model.predict([[2,	1,	28,	18]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict([[0,	0,	51,	207]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
